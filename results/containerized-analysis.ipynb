# %% [markdown]
# # Containerized QUICK GPU Benchmark Analysis
# This notebook shows the performance comparison of containerized QUICK on various GPUs using the molecule [taxol](../input/taxol.in).

# %%
# imports
import pandas as pd

# %%
# Load compiled output data
results_filepath = "./full-results.csv"
results = pd.read_csv(results_filepath)
results["datetime"] = pd.to_datetime(results["datetime"], format="%a %b %d %H:%M:%S %Y")
results.head()
# Out:
#                 gpu_type  gpu_count  containerized  molecule  scf_time  \
# 0  NVIDIA-A100-PCIE-40GB          1           True  morphine  6.643246
# 1  NVIDIA-A100-PCIE-40GB          2           True  morphine  4.214635
# 2  NVIDIA-A100-PCIE-40GB          3           True  morphine  3.806321
# 3  NVIDIA-A100-PCIE-40GB          1           True      psb5  1.299491
# 4  NVIDIA-A100-PCIE-40GB          2           True      psb5  0.904503
#
#    gradient_time  total_time   system            datetime
# 0       8.074201   18.963636  expanse 2024-01-18 10:36:59
# 1       4.474140   13.116883  expanse 2024-01-18 10:37:19
# 2       3.318024   11.496085  expanse 2024-01-18 10:37:33
# 3       1.280677   19.505161  expanse 2024-01-18 10:36:26
# 4       0.755967    5.493714  expanse 2024-01-18 10:36:47

# %%
results.dtypes
# Out:
# gpu_type                 object
# gpu_count                 int64
# containerized              bool
# molecule                 object
# scf_time                float64
# gradient_time           float64
# total_time              float64
# system                   object
# datetime         datetime64[ns]
# dtype: object

# %% [markdown]
# # Taxol Timings for Single GPUs

# %%
# Get dataframe with gpu_type, scf_time, gradient_time & total_time where gpu_count = 1 and molecule=taxol
gpu_count_filter = results["gpu_count"] == 1
molecule_filter = results["molecule"] == "taxol"
containerized_filter = results["containerized"] == True

taxol_timings = results[["gpu_type", "scf_time", "gradient_time", "total_time", "datetime"]].where(gpu_count_filter & molecule_filter & containerized_filter)
taxol_timings.dropna(inplace=True)
taxol_timings = taxol_timings.sort_values(["total_time","datetime"])
taxol_timings
# Out:
#                        gpu_type    scf_time  gradient_time  total_time  \
# 6         NVIDIA-A100-PCIE-40GB   32.691907      50.558595   90.050375
# 180       NVIDIA-A100-80GB-PCIe   32.826639      50.668244   94.558451
# 168       NVIDIA-A100-80GB-PCIe   33.022493      50.690760   94.835815
# 128       NVIDIA-A100-80GB-PCIe   33.201645      50.740466   95.887682
# 142       NVIDIA-A100-80GB-PCIe   33.107761      50.818803   95.957835
# 156       NVIDIA-A100-80GB-PCIe   33.218616      50.820309   96.002668
# 90      NVIDIA-GeForce-RTX-4090   66.570317      33.286316  110.559730
# 114       NVIDIA-A100-80GB-PCIe   58.530119      51.449317  121.925780
# 102       NVIDIA-A100-80GB-PCIe   58.682667      51.409130  122.372365
# 18         Tesla-V100-SXM2-32GB   62.387076      72.390627  142.295767
# 30         Tesla-V100-SXM2-32GB   63.744539      78.865300  150.134496
# 78      NVIDIA-GeForce-RTX-3090  151.647275      96.944185  262.651704
# 66   NVIDIA-GeForce-RTX-2080-Ti  170.513679     109.736870  299.035471
# 54   NVIDIA-GeForce-GTX-1080-Ti  265.092521     205.498805  487.916609
# 42      NVIDIA-GeForce-GTX-1080  366.045118     280.502213  666.499745
#
#                datetime
# 6   2024-01-18 10:37:45
# 180 2024-01-05 00:33:12
# 168 2023-12-15 16:47:04
# 128 2023-12-01 21:58:49
# 142 2023-12-01 22:33:24
# 156 2023-12-11 19:14:21
# 90  2024-01-10 16:51:47
# 114 2023-12-01 20:40:37
# 102 2023-11-30 16:53:44
# 18  2023-12-05 17:19:32
# 30  2023-12-15 08:44:58
# 78  2024-01-06 02:44:48
# 66  2024-01-05 20:40:42
# 54  2024-01-09 17:02:26
# 42  2024-01-08 23:30:21

# %%
# If more than one timing is present, select the most recent timing

# Find the index of the row with max datetime for each GPU
max_datetime_idx = taxol_timings.groupby("gpu_type")["datetime"].idxmax()

# Get the corresponding rows
most_recent_taxol_timings = taxol_timings.loc[max_datetime_idx]
most_recent_taxol_timings
# Out:
#                        gpu_type    scf_time  gradient_time  total_time  \
# 180       NVIDIA-A100-80GB-PCIe   32.826639      50.668244   94.558451
# 6         NVIDIA-A100-PCIE-40GB   32.691907      50.558595   90.050375
# 42      NVIDIA-GeForce-GTX-1080  366.045118     280.502213  666.499745
# 54   NVIDIA-GeForce-GTX-1080-Ti  265.092521     205.498805  487.916609
# 66   NVIDIA-GeForce-RTX-2080-Ti  170.513679     109.736870  299.035471
# 78      NVIDIA-GeForce-RTX-3090  151.647275      96.944185  262.651704
# 90      NVIDIA-GeForce-RTX-4090   66.570317      33.286316  110.559730
# 30         Tesla-V100-SXM2-32GB   63.744539      78.865300  150.134496
#
#                datetime
# 180 2024-01-05 00:33:12
# 6   2024-01-18 10:37:45
# 42  2024-01-08 23:30:21
# 54  2024-01-09 17:02:26
# 66  2024-01-05 20:40:42
# 78  2024-01-06 02:44:48
# 90  2024-01-10 16:51:47
# 30  2023-12-15 08:44:58

# %% [markdown]
# ## Total SCF Time

# %%
scf_time_graph = most_recent_taxol_timings.sort_values("scf_time").plot.bar(x="gpu_type", y="scf_time")
scf_time_graph
# Out:
# <Axes: xlabel='gpu_type'>

# %% [markdown]
# ## Total Gradient Time

# %%
gradient_time_graph = most_recent_taxol_timings.sort_values("gradient_time").plot.bar(x="gpu_type", y="gradient_time")
gradient_time_graph
# Out:
# <Axes: xlabel='gpu_type'>

# %% [markdown]
# ## Total Time

# %%
total_time_graph = most_recent_taxol_timings.sort_values("total_time").plot.bar(x="gpu_type", y="total_time")
total_time_graph
# Out:
# <Axes: xlabel='gpu_type'>

# %%
ax = most_recent_taxol_timings.sort_values("total_time").plot.bar(x="gpu_type", y=["scf_time", "gradient_time", "total_time"])
ax.set_title("QUICK Container Taxol Timings on Various GPUs")
ax.set_xlabel("GPU")
ax.set_ylabel("Time in seconds")
ax
# Out:
# <Axes: title={'center': 'QUICK Container Taxol Timings on Various GPUs'}, xlabel='GPU', ylabel='Time in seconds'>
